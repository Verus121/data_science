# %%
import pandas as pd

# %%
df = pd.read_csv("data/university_rankings.csv")

df.head(10)
# Out:
#                                           university  year rank_display  \
# 0       Massachusetts Institute of Technology (MIT)   2017            1
# 1                                Stanford University  2017            2
# 2                                 Harvard University  2017            3
# 3                            University of Cambridge  2017            4
# 4       California Institute of Technology (Caltech)  2017            5
# 5                               University of Oxford  2017            6
# 6                                                UCL  2017            7
# 7  ETH Zurich - Swiss Federal Institute of Techno...  2017            8
# 8                            Imperial College London  2017            9
# 9                              University of Chicago  2017           10
#
#    score                                               link         country  \
# 0  100.0  https://www.topuniversities.com/universities/m...   United States
# ...

# %%
df.dtypes
# Out:
# university                 object
# year                        int64
# rank_display               object
# score                     float64
# link                       object
# country                    object
# city                       object
# region                     object
# logo                       object
# type                       object
# research_output            object
# student_faculty_ratio     float64
# international_students     object
# size                       object
# faculty_count              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6482 entries, 0 to 6481
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   university              6482 non-null   object
#  1   year                    6482 non-null   int64
#  2   rank_display            6414 non-null   object
#  3   score                   2820 non-null   float64
#  4   link                    6482 non-null   object
#  5   country                 6482 non-null   object
#  6   city                    6304 non-null   object
#  7   region                  6482 non-null   object
#  8   logo                    6482 non-null   object
#  9   type                    6470 non-null   object
#  10  research_output         6480 non-null   object
#  11  student_faculty_ratio   6407 non-null   float64
#  12  international_students  6318 non-null   object
#  13  size                    6480 non-null   object
# ...

# %%
clean_df = df[["university", "year", "rank_display", "score", "country", "city", "region", "type", "research_output", "student_faculty_ratio", "international_students", "size", "faculty_count"]]
usable_df = clean_df.head(100).copy()
usable_df.head()
# Out:
#                                      university  year rank_display  score  \
# 0  Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                           Stanford University  2017            2   98.7
# 2                            Harvard University  2017            3   98.3
# 3                       University of Cambridge  2017            4   97.2
# 4  California Institute of Technology (Caltech)  2017            5   96.9
#
#           country       city         region     type research_output  \
# 0   United States  Cambridge  North America  Private       Very High
# 1   United States   Stanford  North America  Private       Very High
# 2   United States  Cambridge  North America  Private       Very High
# 3  United Kingdom  Cambridge         Europe   Public       Very high
# 4   United States   Pasadena  North America  Private       Very High
#
#    student_faculty_ratio international_students size faculty_count
# ...

# %% [markdown]
# Currently International Students and faculty count is a string, we need it to be int.
#
# year, rank, int stu, faculty
#
# df['Price'] = pd.to_numeric(df['Price'])

# %%
usable_df["rank_display"] = usable_df["rank_display"].astype(int)

# %%
usable_df["international_students"] = usable_df["international_students"].str.replace(',', '').astype(int)

# %%
usable_df["faculty_count"] = usable_df["faculty_count"].str.replace(',', '').astype(int)

# %% [markdown]
# usable_df.head()

# %%
usable_df.head()
# Out:
#                                      university  year  rank_display  score  \
# 0  Massachusetts Institute of Technology (MIT)   2017             1  100.0
# 1                           Stanford University  2017             2   98.7
# 2                            Harvard University  2017             3   98.3
# 3                       University of Cambridge  2017             4   97.2
# 4  California Institute of Technology (Caltech)  2017             5   96.9
#
#           country       city         region     type research_output  \
# 0   United States  Cambridge  North America  Private       Very High
# 1   United States   Stanford  North America  Private       Very High
# 2   United States  Cambridge  North America  Private       Very High
# 3  United Kingdom  Cambridge         Europe   Public       Very high
# 4   United States   Pasadena  North America  Private       Very High
#
#    student_faculty_ratio  international_students size  faculty_count
# ...

# %%
usable_df.dtypes
# Out:
# university                 object
# year                        int64
# rank_display                int64
# score                     float64
# country                    object
# city                       object
# region                     object
# type                       object
# research_output            object
# student_faculty_ratio     float64
# international_students      int64
# size                       object
# faculty_count               int64
# dtype: object

# %% [markdown]
# Export Pandas Dataframe to CSV

# %%
clean_df.to_csv(r'data/clean_university_rankings.csv', index = False)

# %%
cleaned_data_df = pd.read_csv("data/clean_university_rankings.csv")
cleaned_data_df.head()
# Out:
#                                      university  year  rank_display  score  \
# 0  Massachusetts Institute of Technology (MIT)   2017             1  100.0
# 1                           Stanford University  2017             2   98.7
# 2                            Harvard University  2017             3   98.3
# 3                       University of Cambridge  2017             4   97.2
# 4  California Institute of Technology (Caltech)  2017             5   96.9
#
#           country       city         region     type research_output  \
# 0   United States  Cambridge  North America  Private       Very High
# 1   United States   Stanford  North America  Private       Very High
# 2   United States  Cambridge  North America  Private       Very High
# 3  United Kingdom  Cambridge         Europe   Public       Very high
# 4   United States   Pasadena  North America  Private       Very High
#
#    student_faculty_ratio  international_students size  faculty_count
# ...

# %% [markdown]
# Now let's get the same data but from my local postgresql database

# %%
# SQLAlchemy - generates SQL statements from python
# Psycopg2 - communicates your SQL statements to your Postgres database

from sqlalchemy import create_engine
import psycopg2
import pandas as pd

# %%
# Create the connection

engine = create_engine('postgresql://super_andyw:#chill$..12@localhost:5432/mypostgresdb')

# create_engine() creates an engine object that allows you to connect to your database and send queries using python.

# %%
testdf = pd.read_sql_query('''SELECT * FROM rankings;''', engine)
testdf.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3249         try:
# -> 3250             return fn()
#    3251         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %% [markdown]
# lets see what happens now.

# %%
param_dic = {
    "host"      : "localhost",
    "database"  : "mypostgresdb",
    "user"      : "andyw",
    "password"  : "#chill$..12"
}

def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        exit(1) 
    print("Connection successful")
    return conn

def postgresql_to_dataframe(conn, select_query, column_names):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["university", "rank_display", "score", "international_students"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "select * from rankings", column_names)
df.head()
# Out:
# Connecting to the PostgreSQL database...
# connection to server at "localhost" (127.0.0.1), port 5432 failed: FATAL:  password authentication failed for user "andyw"
# connection to server at "localhost" (127.0.0.1), port 5432 failed: FATAL:  password authentication failed for user "andyw"
#
# Connection successful
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4822/1719040686.py in <module>
#       3 column_names = ["university", "rank_display", "score", "international_students"]
#       4 # Execute the "SELECT *" query
# ----> 5 df = postgresql_to_dataframe(conn, "select * from rankings", column_names)
#       6 df.head()
#
# /tmp/ipykernel_4822/2270941417.py in postgresql_to_dataframe(conn, select_query, column_names)
#      23     Tranform a SELECT query into a pandas dataframe
#      24     """
# ---> 25     cursor = conn.cursor()
#      26     try:
# ...

# %% [markdown]
# New, this time with ConnectorX

# %%
import connectorx as cx
import pandas as pd

df = cx.read_sql("postgresql://getdatauser:test123@localhost:5432/mypostgresdb", "SELECT * FROM rankings")

# %%
df.head()
# Out:
#                                      university  year_ranked  global_rank  \
# 0  Massachusetts Institute of Technology (MIT)          2017            1
# 1                           Stanford University         2017            2
# 2                            Harvard University         2017            3
# 3                       University of Cambridge         2017            4
# 4  California Institute of Technology (Caltech)         2017            5
#
#    score         country       city         region university_type  \
# 0  100.0   United States  Cambridge  North America         Private
# 1   98.7   United States   Stanford  North America         Private
# 2   98.3   United States  Cambridge  North America         Private
# 3   97.2  United Kingdom  Cambridge         Europe          Public
# 4   96.9   United States   Pasadena  North America         Private
#
#   research_output  student_faculty_ratio  international_students size  \
# ...

# %% [markdown]
# How to Benchmark?
